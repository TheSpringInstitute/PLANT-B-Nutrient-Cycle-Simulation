# %%
# Restore the path to the plots directory
# %store -r plots_dir

# %%
# Import the below libraries:
"""For faster loading, consider importing the libraries in separate cells."""
# To create reproducible file paths
import os # To interact with the operating system
from pathlib import Path # To create Path objects
import pathlib # To access the object-oriented library for paths

# To work with different types of data
import numpy as np # To work with arrays
import openpyxl # To read XLSX files
import pandas as pd # To work with dataframes

# For visualization and interactive plotting
import matplotlib.pyplot as plt # To import the Pyplot module
from matplotlib.ticker import PercentFormatter # To format percentages

# %%
# Create a designated folder for the organism nutrient data
"""Note: the precise destination of the repository folder will vary from individual to individual."""
organism_nutrient_dir = os.path.join(
    pathlib.Path.home(),
    # In the PLANT-B-Terrarium data folder
    'PLANT-B-Terrarium',
    'data',
    # Specify the destination as inside the "PLANT-B-Nutrient-Cycle-Simulation" data repository
    'PLANT-B-Nutrient-Cycle-Simulation',
    'data',
    'stoichiometry_database'
)

# Create the directory
os.makedirs(organism_nutrient_dir, exist_ok=True)

# %% [markdown]
# It is not possible to download the appropriate files through a Python function because the Dryad server uses a proof-of-work JavaScript check that interrupts non-browser requests. The dataset and README file must be manually downloaded from https://datadryad.org/dataset/doi:10.5061/dryad.3tx95x6r2 and moved to "stoichlife_dir," which is created in the cell below.

# %%
# Create a specific directory for the StoichLife data
stoichlife_dir = os.path.join(organism_nutrient_dir, 'stoichlife_data')
os.makedirs(stoichlife_dir, exist_ok=True)

# Define the file path to the XLSX file
stoichlife_path = os.path.join(stoichlife_dir, "datapaper_2025_02_11.xlsx")

# Save the "data" sheet of the XLSX file as a dataframe
"""The XLSX file also contains a "metadata" and "references" sheet. The "metadata" sheet details what the variables (ex. habitat) are
describing."""
stoichlife_df = pd.read_excel(stoichlife_path, sheet_name="data")

# Display the data
stoichlife_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 11
#       7
#       8 # Save the "data" sheet of the XLSX file as a dataframe
#       9 """The XLSX file also contains a "metadata" and "references" sheet. The "metadata" sheet details what the variables (ex. habitat) are
#      10 describing."""
# ---> 11 stoichlife_df = pd.read_excel(stoichlife_path, sheet_name="data")
#      12
#      13 # Display the data
#      14 stoichlife_df
#
# File c:\Users\livth\miniconda3\envs\plant-b-simulation-env\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File c:\Users\livth\miniconda3\envs\plant-b-simulation-env\Lib\site-packages\pandas\io\excel\_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File c:\Users\livth\miniconda3\envs\plant-b-simulation-env\Lib\site-packages\pandas\io\excel\_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File c:\Users\livth\miniconda3\envs\plant-b-simulation-env\Lib\site-packages\pandas\io\common.py:939, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#    (...)    935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
# --> 939         handle = open(handle, ioargs.mode)
#     940     handles.append(handle)
#     942 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\livth\\PLANT-B-Terrarium\\data\\PLANT-B-Nutrient-Cycle-Simulation\\data\\stoichiometry_database\\stoichlife_data\\datapaper_2025_02_11.xlsx'

# %%
# Look at the columns
stoichlife_df.columns
# Out:
# Index(['data.source1', 'data.type', 'data.provider1', 'lat.dec', 'long.dec',
#        'location', 'habitat.gen', 'habitat', 'kingdom_init', 'phylum_init',
#        'class_init', 'order_init', 'family_init', 'sp.morphosp_init',
#        'kingdom_revised', 'phylum_revised', 'class_revised', 'order_revised',
#        'family_revised', 'sp.morphosp_revised', 'species.level', 'autohetero',
#        'invert.vert.auto', 'taxa.c', 'taxa.n', 'taxa.p', 'taxa.cn', 'taxa.cp',
#        'taxa.np', 'taxa.mass.cn', 'taxa.mass.cp', 'taxa.mass.np',
#        'body.weight.gr', 'temperature', 'radiation', 'N', 'P_ter', 'P_mar'],
#       dtype='str')

# %% [markdown]
# The below definitions for "columns_to_keep" were derived from the metadata tab:
#
# * sp.morphosp_revised: Currently accepted species taxonomy
#
# * class_revised: Currently accepted class taxonomy
#
# * order_revised: Currently accepted order taxonomy
#
# * family_revised: Currently accepted family taxonomy
#
# * habitat: Differentiates terrestrial, aquatic, and marine habitats
#
# * taxa.c: Carbon content of organisms by percentage (%)
#
# * taxa.n: Nitrogen content of organisms by percentage (%)
#
# * taxa.p: Phosphorus content of organisms by percentage (%)
#
# * taxa.cn: Carbon-nitrogen ratio (C:N) in an organism's body
#
# * taxa.cp: Carbon-phosphorus ratio (C:P) in an organism's body
#
# * taxa.np: Nitrogen-phosphorus ratio (N:P) in an organism's body
#
# * taxa.mass.cn: C:N of organisms as mass ratios (C%/N%)
#
# * taxa.mass.cp: C:P of organisms as mass ratios (C%/N%)
#
# * taxa.mass.np: N:P of organisms as mass ratios (N%/P%)
#
# * body.weight.gr: Body dry mass in grams (g)
#
# * N: Global nitrogen availability data
#
# * P_ter: Soil phosphorus data from the Oak Ridge National Laboratories Distributed Active Archive Center
#
# Source: (González et al., 2025)

# %%
# Specify the columns to keep
"""Only columns related to the species's species name and family name and nutrient data will be kept."""
columns_to_keep = ['sp.morphosp_revised', 'class_revised', 'order_revised', 'family_revised', 'habitat', 'taxa.c', 'taxa.n', 'taxa.p', 
                   'taxa.cn', 'taxa.cp', 'taxa.np', 'taxa.mass.cn', 'taxa.mass.cp', 'taxa.mass.np', 'body.weight.gr', 'N', 'P_ter']

# Filter the dataset to keep only the necessary columns
stoichlife_filtered_df = stoichlife_df[columns_to_keep]

# Display the filtered dataframe
stoichlife_filtered_df
# Out:
#          sp.morphosp_revised   class_revised  order_revised  family_revised  \
# 0           Formicidae sp.11         Insecta    Hymenoptera      Formicidae
# 1            Formicidae sp.9         Insecta    Hymenoptera      Formicidae
# 2               Atya lanipes    Malacostraca       Decapoda         Atyidae
# 3        Xiphocaris elongata    Malacostraca       Decapoda  Xiphocarididae
# 4        Xiphocaris elongata    Malacostraca       Decapoda  Xiphocarididae
# ...                      ...             ...            ...             ...
# 28044  Salvelinus fontinalis  Actinopterygii  Salmoniformes      Salmonidae
# 28045  Salvelinus fontinalis  Actinopterygii  Salmoniformes      Salmonidae
# 28046  Salvelinus fontinalis  Actinopterygii  Salmoniformes      Salmonidae
# 28047  Salvelinus fontinalis  Actinopterygii  Salmoniformes      Salmonidae
# 28048  Salvelinus fontinalis  Actinopterygii  Salmoniformes      Salmonidae
#
#            habitat     taxa.c     taxa.n  taxa.p   taxa.cn     taxa.cp  \
# 0      terrestrial        NaN  11.510000    0.17       NaN         NaN
# 1      terrestrial  41.800000   9.190000    0.37  5.304302  291.332886
# 2       freshwater  48.440000  11.740000    0.94  4.811755  132.889673
# 3       freshwater  46.900000  11.460000    1.09  4.772608  110.958684
# 4       freshwater  45.960000  12.640000    1.09  4.240338  108.734779
# ...            ...        ...        ...     ...       ...         ...
# 28044   freshwater  44.493203  12.625693     NaN  4.109661         NaN
# 28045   freshwater  44.234026  12.499746     NaN  4.126889         NaN
# 28046   freshwater  44.730870  13.022505     NaN  4.005717         NaN
# 28047   freshwater  45.114385  13.101184     NaN  4.015799         NaN
# 28048   freshwater  44.563635  13.402909     NaN  3.877475         NaN
#
#           taxa.np  taxa.mass.cn  taxa.mass.cp  taxa.mass.np  body.weight.gr  \
# 0      149.717942           NaN           NaN     67.705882        0.000628
# 1       54.923883      4.548422    112.972973     24.837838        0.000431
# 2       27.617712      4.126065     51.531915     12.489362        0.199900
# 3       23.249069      4.092496     43.027523     10.513761        0.097500
# 4       25.642952      3.636076     42.165138     11.596330        0.109600
# ...           ...           ...           ...           ...             ...
# 28044         NaN      3.524021           NaN           NaN        0.000303
# 28045         NaN      3.538794           NaN           NaN        0.000287
# 28046         NaN      3.434890           NaN           NaN        0.000290
# 28047         NaN      3.443535           NaN           NaN        0.000312
# 28048         NaN      3.324923           NaN           NaN        0.000306
#
#                 N      P_ter
# 0       60.439308  43.495975
# 1       60.439308  43.495975
# 2      104.139830  18.790420
# 3      104.139830  18.790420
# 4      104.139830  21.631483
# ...           ...        ...
# 28044   19.262070        NaN
# 28045   19.262070        NaN
# 28046   19.262070        NaN
# 28047   19.262070        NaN
# 28048   19.262070        NaN
#
# [28049 rows x 17 columns]

# %%
# Filter 'sp.morphosp_revised' for close relatives of the invertebrates
invertebrate_df = stoichlife_filtered_df[stoichlife_filtered_df['sp.morphosp_revised'].isin(['Folsomia fimetaria', 'Platyarthrus sp.'])]

# Display the filtered dataframe
invertebrate_df
# Out:
#       sp.morphosp_revised class_revised     order_revised  family_revised  \
# 22490  Folsomia fimetaria    Collembola  Entomobryomorpha      Isotomidae
# 22505  Folsomia fimetaria    Collembola  Entomobryomorpha      Isotomidae
# 25347    Platyarthrus sp.  Malacostraca           Isopoda  Platyarthridae
#
#            habitat  taxa.c    taxa.n  taxa.p   taxa.cn  taxa.cp  taxa.np  \
# 22490  terrestrial   39.13  9.561228     NaN  4.772695      NaN      NaN
# 22505  terrestrial   39.26  9.792730     NaN  4.675349      NaN      NaN
# 25347  terrestrial     NaN  1.160000     NaN       NaN      NaN      NaN
#
#        taxa.mass.cn  taxa.mass.cp  taxa.mass.np  body.weight.gr            N  \
# 22490      4.092570           NaN           NaN             NaN  1626.260452
# 22505      4.009097           NaN           NaN             NaN  1626.260452
# 25347           NaN           NaN           NaN             NaN  1060.043928
#
#            P_ter
# 22490  16.725162
# 22505  16.725162
# 25347  66.802081

# %%
# Create variables for the average springtail carbon and nitrogen for later use
springtail_c = invertebrate_df.loc[invertebrate_df['sp.morphosp_revised'] == 'Folsomia fimetaria', 'taxa.c'].mean() # For carbon
springtail_n = invertebrate_df.loc[invertebrate_df['sp.morphosp_revised'] == 'Folsomia fimetaria', 'taxa.n'].mean() # For nitrogen

# Average the C:N ratio for the chosen springtail species
springtail_c_n_ratio = invertebrate_df.loc[invertebrate_df['sp.morphosp_revised'] == 'Folsomia fimetaria', 'taxa.cn'].mean()

# Print the carbon and nitrogen concentration and C:N ratio with appropriate labeling
print('Springtail carbon concentration (%):')
print(springtail_c)

print('\nSpringtail nitrogen concentration (%):')
print(springtail_n)

print('\nSpringtail C:N ratio:')
print(springtail_c_n_ratio)
# Out:
# Springtail carbon concentration (%):
# 39.195
#
# Springtail nitrogen concentration (%):
# 9.6769791175
#
# Springtail C:N ratio:
# 4.72402186718267

# %%
# Filter for Porcellio monticola entries that have carbon data
'''Note: Porcellio monticola is the closest relative to T. tomentosa in the database that has carbon data (Schmidt, 2008).'''
isopod_df = stoichlife_filtered_df[
    (stoichlife_filtered_df['sp.morphosp_revised'] == 'Porcellio monticola') 
    & (stoichlife_filtered_df['taxa.c'].notna())
]

# Display the dataframe
isopod_df
# Out:
#        sp.morphosp_revised class_revised order_revised  family_revised  \
# 23882  Porcellio monticola  Malacostraca       Isopoda  Porcellionidae
# 23894  Porcellio monticola  Malacostraca       Isopoda  Porcellionidae
#
#            habitat  taxa.c  taxa.n  taxa.p   taxa.cn  taxa.cp  taxa.np  \
# 23882  terrestrial   32.59    6.85     NaN  5.548317      NaN      NaN
# 23894  terrestrial   31.50    7.00     NaN  5.247833      NaN      NaN
#
#        taxa.mass.cn  taxa.mass.cp  taxa.mass.np  body.weight.gr            N  \
# 23882      4.757664           NaN           NaN             NaN  1429.542241
# 23894      4.500000           NaN           NaN             NaN  1429.542241
#
#           P_ter
# 23882  31.86526
# 23894  31.86526

# %%
# Calculate the average nitrogen body percentage average in the close relative of the isopod
isopod_c = isopod_df['taxa.c'].mean()

# Create a variable for the isopod nitrogen body percentage
isopod_n = invertebrate_df.loc[invertebrate_df['sp.morphosp_revised'] == 'Platyarthrus sp.', 'taxa.n'].iloc[0]

# Calculate the isopod C:N ratio
isopod_c_n_ratio = isopod_c / isopod_n

# Print the carbon and nitrogen concentration and C:N ratio with appropriate labeling
print('Isopod carbon concentration (%):')
print(isopod_c)

print('\nIsopod nitrogen concentration (%):')
print(isopod_n)

print('\nIsopod C:N ratio:')
print(isopod_c_n_ratio)
# Out:
# Isopod carbon concentration (%):
# 32.045
#
# Isopod nitrogen concentration (%):
# 1.16
#
# Isopod C:N ratio:
# 27.625000000000004

# %%
# Filter for terrestrial mosses in the order Bryopsida that have nitrogen data
moss_df = stoichlife_filtered_df[
    (stoichlife_filtered_df['class_revised'] == 'Bryopsida') &
    (stoichlife_filtered_df['habitat'] == 'terrestrial') &
    (stoichlife_filtered_df['taxa.n'].notna())
]

# Display the dataframe
moss_df
# Out:
#              sp.morphosp_revised class_revised order_revised  \
# 17795        Ctenidium molluscum     Bryopsida      Hypnales
# 17912            Bryum argenteum     Bryopsida       Bryales
# 17913            Bryum capillare     Bryopsida       Bryales
# 17914        Ceratodon purpureus     Bryopsida    Dicranales
# 17927          Grimmia pulvinata     Bryopsida    Grimmiales
# 17928     Homalothecium sericeum     Bryopsida      Hypnales
# 17929       Hypnum cupressiforme     Bryopsida      Hypnales
# 17942    Racomitrium lanuginosum     Bryopsida    Grimmiales
# 17944            Tortula muralis     Bryopsida     Pottiales
# 18046   Calliergonella cuspidata     Bryopsida      Hypnales
# 18076      Thuidium tamariscinum     Bryopsida      Hypnales
# 18296     Calliergon cordifolium     Bryopsida      Hypnales
# 18418         Dicranum scoparium     Bryopsida    Dicranales
# 18419       Pleurozium schreberi     Bryopsida      Hypnales
# 18420  Ptilium crista-castrensis     Bryopsida      Hypnales
# 18421    Racomitrium lanuginosum     Bryopsida    Grimmiales
# 18422     Rhytidiadelphus loreus     Bryopsida      Hypnales
# 18463       Pleurozium schreberi     Bryopsida      Hypnales
# 18464       Pleurozium schreberi     Bryopsida      Hypnales
# 18561       Pleurozium schreberi     Bryopsida      Hypnales
# 18571       Pleurozium schreberi     Bryopsida      Hypnales
# 18888         Tomentypnum nitens     Bryopsida      Hypnales
# 18889         Tomentypnum nitens     Bryopsida      Hypnales
#
#          family_revised      habitat  taxa.c  taxa.n  taxa.p  taxa.cn  \
# 17795         Hypnaceae  terrestrial     NaN    1.90   0.090      NaN
# 17912          Bryaceae  terrestrial     NaN    1.43     NaN      NaN
# 17913          Bryaceae  terrestrial     NaN    1.67     NaN      NaN
# 17914      Ditrichaceae  terrestrial     NaN    1.78     NaN      NaN
# 17927       Grimmiaceae  terrestrial     NaN    1.79     NaN      NaN
# 17928  Brachytheciaceae  terrestrial     NaN    2.04     NaN      NaN
# 17929         Hypnaceae  terrestrial     NaN    1.22     NaN      NaN
# 17942       Grimmiaceae  terrestrial     NaN    0.90     NaN      NaN
# 17944        Pottiaceae  terrestrial     NaN    1.53     NaN      NaN
# 18046   Amblystegiaceae  terrestrial     NaN    1.40     NaN      NaN
# 18076       Thuidiaceae  terrestrial     NaN    1.58     NaN      NaN
# 18296   Amblystegiaceae  terrestrial     NaN    2.80     NaN      NaN
# 18418       Dicranaceae  terrestrial     NaN    0.84     NaN      NaN
# 18419     Hylocomiaceae  terrestrial     NaN    0.59     NaN      NaN
# 18420         Hypnaceae  terrestrial     NaN    0.68     NaN      NaN
# 18421       Grimmiaceae  terrestrial     NaN    0.71     NaN      NaN
# 18422     Hylocomiaceae  terrestrial     NaN    0.54     NaN      NaN
# 18463     Hylocomiaceae  terrestrial     NaN    1.30   0.290      NaN
# 18464     Hylocomiaceae  terrestrial     NaN    1.20   0.150      NaN
# 18561     Hylocomiaceae  terrestrial     NaN    0.70   0.110      NaN
# 18571     Hylocomiaceae  terrestrial     NaN    0.80   0.110      NaN
# 18888  Brachytheciaceae  terrestrial     NaN    0.91   0.120      NaN
# 18889  Brachytheciaceae  terrestrial     NaN    0.75   0.069      NaN
#
#        taxa.cp    taxa.np  taxa.mass.cn  taxa.mass.cp  taxa.mass.np  \
# 17795      NaN  46.682976           NaN           NaN     21.111111
# 17912      NaN        NaN           NaN           NaN           NaN
# 17913      NaN        NaN           NaN           NaN           NaN
# 17914      NaN        NaN           NaN           NaN           NaN
# 17927      NaN        NaN           NaN           NaN           NaN
# 17928      NaN        NaN           NaN           NaN           NaN
# 17929      NaN        NaN           NaN           NaN           NaN
# 17942      NaN        NaN           NaN           NaN           NaN
# 17944      NaN        NaN           NaN           NaN           NaN
# 18046      NaN        NaN           NaN           NaN           NaN
# 18076      NaN        NaN           NaN           NaN           NaN
# 18296      NaN        NaN           NaN           NaN           NaN
# 18418      NaN        NaN           NaN           NaN           NaN
# 18419      NaN        NaN           NaN           NaN           NaN
# 18420      NaN        NaN           NaN           NaN           NaN
# 18421      NaN        NaN           NaN           NaN           NaN
# 18422      NaN        NaN           NaN           NaN           NaN
# 18463      NaN   9.912719           NaN           NaN      4.482759
# 18464      NaN  17.690391           NaN           NaN      8.000000
# 18561      NaN  14.071902           NaN           NaN      6.363636
# 18571      NaN  16.082174           NaN           NaN      7.272727
# 18888      NaN  16.769016           NaN           NaN      7.583333
# 18889      NaN  24.035857           NaN           NaN     10.869565
#
#        body.weight.gr   N  P_ter
# 17795             NaN NaN    NaN
# 17912             NaN NaN    NaN
# 17913             NaN NaN    NaN
# 17914             NaN NaN    NaN
# 17927             NaN NaN    NaN
# 17928             NaN NaN    NaN
# 17929             NaN NaN    NaN
# 17942             NaN NaN    NaN
# 17944             NaN NaN    NaN
# 18046             NaN NaN    NaN
# 18076             NaN NaN    NaN
# 18296             NaN NaN    NaN
# 18418             NaN NaN    NaN
# 18419             NaN NaN    NaN
# 18420             NaN NaN    NaN
# 18421             NaN NaN    NaN
# 18422             NaN NaN    NaN
# 18463             NaN NaN    NaN
# 18464             NaN NaN    NaN
# 18561             NaN NaN    NaN
# 18571             NaN NaN    NaN
# 18888             NaN NaN    NaN
# 18889             NaN NaN    NaN

# %%
# State the average carbon content for the model moss
"""Note: The bonfire moss (Funaria hygrometrica), a close relative of P. patens, is grouped with moss that have an average carbon dry mass 
content of 44.4% (Huotari et al., 2009)."""
moss_c = 44.4

# Calculate the average nitrogen percentage in the mosses
moss_n = moss_df['taxa.n'].mean()

# Calculate the C:N ratio for the moss
moss_c_n_ratio = moss_c / moss_n

# Print the carbon and nitrogen concentration and C:N ratio with appropriate labeling
print('Moss carbon concentration (%):')
print(moss_c)

print('\nMoss nitrogen concentration (%):')
print(moss_n)

print('\nMoss C:N ratio:')
print(moss_c_n_ratio)
# Out:
# Moss carbon concentration (%):
# 44.4
#
# Moss nitrogen concentration (%):
# 1.2634782608695652
#
# Moss C:N ratio:
# 35.141087405368204

# %%
# Compile all stoichiometry species entries into one dataframe
species_df = pd.concat(
    [invertebrate_df, isopod_df, moss_df],
    ignore_index=True
)

# Display the dataframe
species_df
# Out:
#           sp.morphosp_revised class_revised     order_revised  \
# 0          Folsomia fimetaria    Collembola  Entomobryomorpha
# 1          Folsomia fimetaria    Collembola  Entomobryomorpha
# 2            Platyarthrus sp.  Malacostraca           Isopoda
# 3         Porcellio monticola  Malacostraca           Isopoda
# 4         Porcellio monticola  Malacostraca           Isopoda
# 5         Ctenidium molluscum     Bryopsida          Hypnales
# 6             Bryum argenteum     Bryopsida           Bryales
# 7             Bryum capillare     Bryopsida           Bryales
# 8         Ceratodon purpureus     Bryopsida        Dicranales
# 9           Grimmia pulvinata     Bryopsida        Grimmiales
# 10     Homalothecium sericeum     Bryopsida          Hypnales
# 11       Hypnum cupressiforme     Bryopsida          Hypnales
# 12    Racomitrium lanuginosum     Bryopsida        Grimmiales
# 13            Tortula muralis     Bryopsida         Pottiales
# 14   Calliergonella cuspidata     Bryopsida          Hypnales
# 15      Thuidium tamariscinum     Bryopsida          Hypnales
# 16     Calliergon cordifolium     Bryopsida          Hypnales
# 17         Dicranum scoparium     Bryopsida        Dicranales
# 18       Pleurozium schreberi     Bryopsida          Hypnales
# 19  Ptilium crista-castrensis     Bryopsida          Hypnales
# 20    Racomitrium lanuginosum     Bryopsida        Grimmiales
# 21     Rhytidiadelphus loreus     Bryopsida          Hypnales
# 22       Pleurozium schreberi     Bryopsida          Hypnales
# 23       Pleurozium schreberi     Bryopsida          Hypnales
# 24       Pleurozium schreberi     Bryopsida          Hypnales
# 25       Pleurozium schreberi     Bryopsida          Hypnales
# 26         Tomentypnum nitens     Bryopsida          Hypnales
# 27         Tomentypnum nitens     Bryopsida          Hypnales
#
#       family_revised      habitat  taxa.c    taxa.n  taxa.p   taxa.cn  \
# 0         Isotomidae  terrestrial   39.13  9.561228     NaN  4.772695
# 1         Isotomidae  terrestrial   39.26  9.792730     NaN  4.675349
# 2     Platyarthridae  terrestrial     NaN  1.160000     NaN       NaN
# 3     Porcellionidae  terrestrial   32.59  6.850000     NaN  5.548317
# 4     Porcellionidae  terrestrial   31.50  7.000000     NaN  5.247833
# 5          Hypnaceae  terrestrial     NaN  1.900000   0.090       NaN
# 6           Bryaceae  terrestrial     NaN  1.430000     NaN       NaN
# 7           Bryaceae  terrestrial     NaN  1.670000     NaN       NaN
# 8       Ditrichaceae  terrestrial     NaN  1.780000     NaN       NaN
# 9        Grimmiaceae  terrestrial     NaN  1.790000     NaN       NaN
# 10  Brachytheciaceae  terrestrial     NaN  2.040000     NaN       NaN
# 11         Hypnaceae  terrestrial     NaN  1.220000     NaN       NaN
# 12       Grimmiaceae  terrestrial     NaN  0.900000     NaN       NaN
# 13        Pottiaceae  terrestrial     NaN  1.530000     NaN       NaN
# 14   Amblystegiaceae  terrestrial     NaN  1.400000     NaN       NaN
# 15       Thuidiaceae  terrestrial     NaN  1.580000     NaN       NaN
# 16   Amblystegiaceae  terrestrial     NaN  2.800000     NaN       NaN
# 17       Dicranaceae  terrestrial     NaN  0.840000     NaN       NaN
# 18     Hylocomiaceae  terrestrial     NaN  0.590000     NaN       NaN
# 19         Hypnaceae  terrestrial     NaN  0.680000     NaN       NaN
# 20       Grimmiaceae  terrestrial     NaN  0.710000     NaN       NaN
# 21     Hylocomiaceae  terrestrial     NaN  0.540000     NaN       NaN
# 22     Hylocomiaceae  terrestrial     NaN  1.300000   0.290       NaN
# 23     Hylocomiaceae  terrestrial     NaN  1.200000   0.150       NaN
# 24     Hylocomiaceae  terrestrial     NaN  0.700000   0.110       NaN
# 25     Hylocomiaceae  terrestrial     NaN  0.800000   0.110       NaN
# 26  Brachytheciaceae  terrestrial     NaN  0.910000   0.120       NaN
# 27  Brachytheciaceae  terrestrial     NaN  0.750000   0.069       NaN
#
#     taxa.cp    taxa.np  taxa.mass.cn  taxa.mass.cp  taxa.mass.np  \
# 0       NaN        NaN      4.092570           NaN           NaN
# 1       NaN        NaN      4.009097           NaN           NaN
# 2       NaN        NaN           NaN           NaN           NaN
# 3       NaN        NaN      4.757664           NaN           NaN
# 4       NaN        NaN      4.500000           NaN           NaN
# 5       NaN  46.682976           NaN           NaN     21.111111
# 6       NaN        NaN           NaN           NaN           NaN
# 7       NaN        NaN           NaN           NaN           NaN
# 8       NaN        NaN           NaN           NaN           NaN
# 9       NaN        NaN           NaN           NaN           NaN
# 10      NaN        NaN           NaN           NaN           NaN
# 11      NaN        NaN           NaN           NaN           NaN
# 12      NaN        NaN           NaN           NaN           NaN
# 13      NaN        NaN           NaN           NaN           NaN
# 14      NaN        NaN           NaN           NaN           NaN
# 15      NaN        NaN           NaN           NaN           NaN
# 16      NaN        NaN           NaN           NaN           NaN
# 17      NaN        NaN           NaN           NaN           NaN
# 18      NaN        NaN           NaN           NaN           NaN
# 19      NaN        NaN           NaN           NaN           NaN
# 20      NaN        NaN           NaN           NaN           NaN
# 21      NaN        NaN           NaN           NaN           NaN
# 22      NaN   9.912719           NaN           NaN      4.482759
# 23      NaN  17.690391           NaN           NaN      8.000000
# 24      NaN  14.071902           NaN           NaN      6.363636
# 25      NaN  16.082174           NaN           NaN      7.272727
# 26      NaN  16.769016           NaN           NaN      7.583333
# 27      NaN  24.035857           NaN           NaN     10.869565
#
#     body.weight.gr            N      P_ter
# 0              NaN  1626.260452  16.725162
# 1              NaN  1626.260452  16.725162
# 2              NaN  1060.043928  66.802081
# 3              NaN  1429.542241  31.865260
# 4              NaN  1429.542241  31.865260
# 5              NaN          NaN        NaN
# 6              NaN          NaN        NaN
# 7              NaN          NaN        NaN
# 8              NaN          NaN        NaN
# 9              NaN          NaN        NaN
# 10             NaN          NaN        NaN
# 11             NaN          NaN        NaN
# 12             NaN          NaN        NaN
# 13             NaN          NaN        NaN
# 14             NaN          NaN        NaN
# 15             NaN          NaN        NaN
# 16             NaN          NaN        NaN
# 17             NaN          NaN        NaN
# 18             NaN          NaN        NaN
# 19             NaN          NaN        NaN
# 20             NaN          NaN        NaN
# 21             NaN          NaN        NaN
# 22             NaN          NaN        NaN
# 23             NaN          NaN        NaN
# 24             NaN          NaN        NaN
# 25             NaN          NaN        NaN
# 26             NaN          NaN        NaN
# 27             NaN          NaN        NaN

# %%
# Create a path to save gbif_gdf as a CSV in the first StoichLife folder
species_path = os.path.join(organism_nutrient_dir, "Terrarium_Species_Stoichiometry.csv")

# Save gbif_gdf as a CSV
species_df.to_csv(organism_nutrient_dir, index=False)

# %%
# Create a dictionary that groups the numeric values by species and element
species_elemental_variables = {
    'Trichorhina tomentosa': {'Carbon (C)': isopod_c, 'Nitrogen (N)': isopod_n},
    'Folsomia candida': {'Carbon (C)': springtail_c, 'Nitrogen (N)': springtail_n},
    'Physcomitrium patens': {'Carbon (C)': moss_c, 'Nitrogen (N)': moss_n},
}

# Create a function generates a grouped bar chart of elemental composition by percent dry mass for each PLANT-B species:
def plot_elemental_composition(species_elemental_variables):
    """
    Parameters:
    species_elemental_variables (dict): A dictionary that groups elemental composition by species and element

    Returns:
    Grouped bar chart
    """
    # Extract the species and element names from the dictionary
    species = list(species_elemental_variables.keys())
    carbon = [species_elemental_variables[sp]['Carbon (C)'] for sp in species]
    nitrogen = [species_elemental_variables[sp]['Nitrogen (N)'] for sp in species]

     # Set the bar positions and width
    x = np.arange(len(species))
    width = 0.35

    # Create the figure and plotting surface
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot the carbon and nitrogen bars and set their colors
    carbon_bars = ax.bar(x - width/2, carbon, width, label='Carbon (C)', color='#1F6382') # Color the carbon bars dark turquoise
    nitrogen_bars = ax.bar(x + width/2, nitrogen, width, label='Nitrogen (N)', color='#2ECC71') # Color the nitrogen bars bright green

    # Format the titles and axes labels
    ax.set_title('Elemental Composition of PLANT-B Species by Percent Dry Mass', fontsize=14) # Set the plot title
    ax.set_xlabel('Species') # Set the x-axis label
    ax.set_ylabel('Percent Dry Mass (%)') # Set the y-axis label
    ax.set_xticks(x) # Group the labels correctly
    ax.set_xticklabels(species, style='italic') # Italicize the species names

    # Format the y-axis as a percentage
    ax.yaxis.set_major_formatter(PercentFormatter(xmax=100, decimals=2))
    ax.set_ylim(0, 50)
    ax.yaxis.grid(True, linestyle='-', linewidth=0.5, alpha=0.4)
    ax.set_axisbelow(True)

    # Create a legend titled "Element" and anchor it to the right
    ax.legend(title='Element', loc='center left', bbox_to_anchor=(1.0, 0.5), frameon=False)

    # Add value labels above each bar
    for bars in [carbon_bars, nitrogen_bars]:
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}%',
                        xy=(bar.get_x() + bar.get_width()/2, height),
                        xytext=(0, 3), textcoords="offset points",
                        ha='center', va='bottom', fontsize=9)
            
    # Apply a tight layout
    plt.tight_layout()

    # Save the plot as a png image to the "plots" folder
    plt.savefig(
        os.path.join(plots_dir, "PLANT-B_Species_Dry_Mass_Elemental_Composition.png"),
        dpi=300,
        bbox_inches="tight"
    )

    # Return the figure and axes
    return fig, ax

# Call the function
plot_elemental_composition(species_elemental_variables)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Elemental Composition of PLANT-B Species by Percent Dry Mass'}, xlabel='Species', ylabel='Percent Dry Mass (%)'>)

# %%
# %store isopod_c_n_ratio isopod_c isopod_n springtail_c_n_ratio springtail_c springtail_n moss_c_n_ratio moss_c moss_n
# Out:
# Stored 'isopod_c_n_ratio' (float64)
# Stored 'isopod_c' (float64)
# Stored 'isopod_n' (float64)
# Stored 'springtail_c_n_ratio' (float64)
# Stored 'springtail_c' (float64)
# Stored 'springtail_n' (float64)
# Stored 'moss_c_n_ratio' (float64)
# Stored 'moss_c' (float)
# Stored 'moss_n' (float64)

# %% [markdown]
# Data Sources
#
# González, A. L., Merder, J., Andraczek, K., Brose, U., Filipiak, M., Harpole, W. S., Hillebrand, H., Jackson, M. C., Jochum, M., Leroux, S. J., Nessel, M. P., Onstein, R. E., Paseka, R., Perry, G. L. W., Rugenski, A., Sitters, J., Sperfeld, E., Striebel, M., Zandona, E., Aymes, J.-C., Blanckaert, A., Bluhm, S. L., Doi, H., Eisenhauer, N., Farjalla, V. F., Hood, J., Kratina, P., Labonne, J., Lovelock, C. E., Moody, E. K., Mozsár, A., Nash, L., Pollierer, M. M., Potapov, A., Romero, G. Q., Roussel, J.-M., Scheu, S., Scheunemann, N., Seeber, J., Steinwandter, M., Susanti, W. I., Tiunov, A., & Dézerald, O. (2025). StoichLife: A Global Dataset of Plant and Animal Elemental Content. *Scientific Data*, *12*(1). https://doi.org/10.1038/s41597-025-04852-w
#
# González, A. L., Merder, J., Andraczek, K., Brose, U., Filipiak, M., Harpole, W. S., Hillebrand, H., Jackson, M. C., Jochum, M., Leroux, S. J., Nessel, M. P., Onstein, R. E., Paseka, R., Perry, G. L. W., Rugenski, A., Sitters, J., Sperfeld, E., Striebel, M., Zandona, E., Aymes, J.-C., Blanckaert, A., Bluhm, S. L., Doi, H., Eisenhauer, N., Farjalla, V. F., Hood, J., Kratina, P., Labonne, J., Lovelock, C. E., Moody, E. K., Mozsár, A., Nash, L., Pollierer, M. M., Potapov, A., Romero, G. Q., Roussel, J.-M., Scheu, S., Scheunemann, N., Seeber, J., Steinwandter, M., Susanti, W. I., Tiunov, A., & Dézerald, O. (2025). StoichLife: A global database of plant and animal elemental content [Dataset]. *Dryad*. https://doi.org/10.5061/dryad.3tx95x6r2
#
# Huotari, N., Tillman-Sutela, E., & Kubin, E. (2009). Ground vegetation exceeds tree seedlings in early biomass production and carbon stock on an ash-fertilized cut-away peatland. *Biomass and Bioenergy*, *33*(9), 1108–1115. https://doi.org/10.1016/j.biombioe.2009.05.009
#
# Schmidt, C. (2008). Contribution to the phylogenetic system of the Crinocheta (Crustacea, Isopoda). Part 2. (Oniscoidea to Armadillidiidae). *Zoosystematics and Evolution*, *79*(1), 3–179. https://doi.org/10.1002/mmnz.20030790102
